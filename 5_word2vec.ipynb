# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5243, 3082, 12, 6, 195, 2, 3136, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'originated', 'anarchism', 'of', 'originated', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.972899
# Nearest to these: sadly, futures, presses, passage, attention, hitomaro, demyelinating, antonine,
# Nearest to their: rambam, pkn, micrometer, dissipates, gases, pomerania, melito, hol,
# Nearest to to: thirtieth, konar, forgets, tux, theseus, discreet, lorica, gallop,
# Nearest to are: dorothea, breslau, resumption, paged, intersex, pun, spree, bahamas,
# Nearest to were: expound, terrain, germany, animator, lifestyle, kickapoo, govt, amplification,
# Nearest to have: battleground, celibate, utopian, dawkins, differentiate, profound, rrna, farrell,
# Nearest to some: albumin, porters, disdained, cockney, jackie, superficial, referendums, muriel,
# Nearest to people: room, dance, heraldry, levellers, attenborough, victor, conectiva, relationships,
# Nearest to in: rowing, mountain, koestler, tycoon, evidently, circle, christy, rembrandt,
# Nearest to who: reciprocating, victoria, botham, rriais, biloxi, staff, hitchens, astray,
# Nearest to also: hillsdale, selwyn, kipsigis, tortuous, grimaldi, themis, inverted, bordered,
# Nearest to about: duo, cruijff, available, ww, filmmaking, liberia, carr, probabilities,
# Nearest to one: disturbance, sensation, fenrir, dhcp, altitude, bipartite, fairer, teleology,
# Nearest to but: conscience, natasha, porvoo, sparing, presumptive, remington, tempered, nipples,
# Nearest to may: ere, drake, ordinated, nye, lin, poured, doctrine, cai,
# Nearest to world: heritable, cheapest, palatine, wives, datura, atreides, mick, cheats,
# Average loss at step 2000: 4.364968
# Average loss at step 4000: 3.868655
# Average loss at step 6000: 3.785945
# Average loss at step 8000: 3.684265
# Average loss at step 10000: 3.619189
# Nearest to these: antonine, conclave, sadly, minutemen, webb, fermilab, krantz, demyelinating,
# Nearest to their: his, its, the, melito, her, fisch, guzm, micrometer,
# Nearest to to: gallop, would, penned, reissue, forgets, pigeons, anconia, with,
# Nearest to are: were, is, have, wang, was, menstruation, hamadan, unwilling,
# Nearest to were: are, was, have, devoutly, lip, is, amplification, alive,
# Nearest to have: be, had, are, hampden, were, has, rodrigo, ozzie,
# Nearest to some: many, evi, risked, shoshone, their, merry, trivia, brownish,
# Nearest to people: room, mccartney, catchphrase, utilizes, tolerances, attitude, tambo, thug,
# Nearest to in: of, from, at, with, on, bondage, gilman, braque,
# Nearest to who: he, tigers, they, also, and, rriais, jng, which,
# Nearest to also: teeth, who, gaseous, reverted, today, myelogenous, hammered, now,
# Nearest to about: hellish, flavorings, cruijff, filmmaking, isotope, untested, duo, happier,
# Nearest to one: two, three, six, eight, five, four, restless, seven,
# Nearest to but: does, rebuked, palacio, may, or, although, hill, barbiturates,
# Nearest to may: can, might, ordinated, would, abydos, could, but, factors,
# Nearest to world: restless, parameter, heritable, pivotal, enforcing, steric, evaporated, puts,
# Average loss at step 12000: 3.608305
# Average loss at step 14000: 3.571056
# Average loss at step 16000: 3.406696
# Average loss at step 18000: 3.457936
# Average loss at step 20000: 3.544474
# Nearest to these: many, some, all, antonine, such, conclave, other, which,
# Nearest to their: his, its, the, her, some, fisch, our, prosper,
# Nearest to to: pigeons, would, forgets, will, could, not, for, reich,
# Nearest to are: were, is, have, wang, was, being, other, resumption,
# Nearest to were: are, was, have, had, is, by, be, being,
# Nearest to have: had, has, were, be, are, counseling, decoy, dawkins,
# Nearest to some: many, these, several, all, their, evi, other, bretagne,
# Nearest to people: room, mccartney, utilizes, catchphrase, tambo, thug, tyre, mortem,
# Nearest to in: at, on, during, from, with, bondage, of, by,
# Nearest to who: he, which, they, also, tigers, numerator, she, impaled,
# Nearest to also: which, often, who, now, not, gaseous, always, today,
# Nearest to about: hellish, isotope, flavorings, nernst, duo, disabled, mejid, untested,
# Nearest to one: two, three, four, seven, eight, five, six, nine,
# Nearest to but: however, although, and, which, does, if, brasilia, that,
# Nearest to may: can, would, could, might, must, will, abydos, should,
# Nearest to world: heritable, cheapest, restless, parameter, playfulness, pivotal, rationalized, enforcing,
# Average loss at step 22000: 3.503601
# Average loss at step 24000: 3.492481
# Average loss at step 26000: 3.482986
# Average loss at step 28000: 3.484736
# Average loss at step 30000: 3.501588
# Nearest to these: some, many, all, such, they, their, which, several,
# Nearest to their: its, his, her, the, some, our, these, fisch,
# Nearest to to: will, can, mamadou, gallop, not, could, barbarian, would,
# Nearest to are: were, is, have, discerned, these, julmust, those, while,
# Nearest to were: are, was, have, had, been, being, those, is,
# Nearest to have: had, has, were, are, be, decoy, matlab, do,
# Nearest to some: many, these, several, other, all, their, most, bretagne,
# Nearest to people: room, utilizes, mccartney, fluids, thug, mortem, tyre, luncheon,
# Nearest to in: at, during, on, from, of, under, and, by,
# Nearest to who: he, they, she, tigers, also, which, impaled, and,
# Nearest to also: often, always, now, who, which, gaseous, it, teeth,
# Nearest to about: hellish, mejid, isotope, flavorings, untested, castrati, supper, treaty,
# Nearest to one: two, seven, four, eight, nine, three, five, six,
# Nearest to but: however, although, and, which, though, if, or, require,
# Nearest to may: can, would, could, will, must, might, should, cannot,
# Nearest to world: heritable, battle, enforcing, playfulness, steric, parameter, summits, pivotal,
# Average loss at step 32000: 3.502179
# Average loss at step 34000: 3.493331
# Average loss at step 36000: 3.454002
# Average loss at step 38000: 3.298675
# Average loss at step 40000: 3.425632
# Nearest to these: many, some, they, such, those, several, different, their,
# Nearest to their: its, his, her, the, fisch, our, some, these,
# Nearest to to: gallop, antrim, could, forgets, can, barbarian, shooting, reissue,
# Nearest to are: were, have, is, while, wang, be, include, those,
# Nearest to were: are, have, was, had, being, those, been, be,
# Nearest to have: had, has, were, are, be, counseling, include, bionic,
# Nearest to some: many, these, several, both, those, other, their, most,
# Nearest to people: men, fluids, shaughnessy, elmore, tolerances, captures, room, citeaux,
# Nearest to in: during, forecasts, of, for, on, and, from, at,
# Nearest to who: he, which, they, also, often, she, tigers, that,
# Nearest to also: often, which, sometimes, still, commonly, now, never, who,
# Nearest to about: hellish, parnassus, oldies, over, mejid, isotope, untested, supper,
# Nearest to one: seven, eight, two, six, four, three, five, nine,
# Nearest to but: however, although, and, tabloid, though, it, still, which,
# Nearest to may: can, would, could, must, will, might, should, cannot,
# Nearest to world: steric, parameter, battle, playfulness, heritable, centaur, summits, criminals,
# Average loss at step 42000: 3.441832
# Average loss at step 44000: 3.449562
# Average loss at step 46000: 3.451347
# Average loss at step 48000: 3.351560
# Average loss at step 50000: 3.384446
# Nearest to these: some, many, both, such, several, they, those, various,
# Nearest to their: its, his, her, the, our, whose, your, fisch,
# Nearest to to: would, forgets, prepositions, could, duckworth, must, will, can,
# Nearest to are: were, have, is, those, wang, be, being, these,
# Nearest to were: are, have, was, had, those, be, being, been,
# Nearest to have: had, has, were, are, be, include, bionic, counseling,
# Nearest to some: many, several, these, both, those, various, other, all,
# Nearest to people: men, children, person, zubaydah, bundaberg, pollack, utilizes, luncheon,
# Nearest to in: during, from, on, of, kaaba, under, gilman, across,
# Nearest to who: he, which, she, also, they, tigers, generally, have,
# Nearest to also: often, which, now, generally, sometimes, still, hammered, always,
# Nearest to about: oldies, hellish, volatility, parnassus, garbled, over, comma, supper,
# Nearest to one: two, eight, six, four, seven, three, nine, five,
# Nearest to but: however, and, although, while, when, than, since, though,
# Nearest to may: can, would, could, must, will, might, should, cannot,
# Nearest to world: battle, playfulness, steric, centaur, civil, heritable, pollen, summits,
# Average loss at step 52000: 3.433042
# Average loss at step 54000: 3.429703
# Average loss at step 56000: 3.440191
# Average loss at step 58000: 3.398320
# Average loss at step 60000: 3.391904
# Nearest to these: many, some, both, such, those, they, several, all,
# Nearest to their: its, his, her, the, whose, our, some, these,
# Nearest to to: forgets, substituting, anconia, tux, will, would, prepositions, accented,
# Nearest to are: were, is, have, including, discerned, be, those, but,
# Nearest to were: are, was, have, had, be, including, been, those,
# Nearest to have: has, had, are, were, be, include, bionic, produce,
# Nearest to some: many, several, these, various, both, those, each, all,
# Nearest to people: men, those, shaughnessy, elmore, children, person, zubaydah, fluids,
# Nearest to in: during, within, of, among, at, throughout, including, from,
# Nearest to who: he, she, also, they, which, luxurious, still, both,
# Nearest to also: often, now, generally, still, which, never, always, sometimes,
# Nearest to about: oldies, supper, over, parnassus, hellish, garbled, spectrometer, volatility,
# Nearest to one: two, seven, three, six, four, five, eight, nine,
# Nearest to but: however, although, and, though, while, since, see, are,
# Nearest to may: can, would, could, must, will, might, should, cannot,
# Nearest to world: attainder, enforcing, largest, civil, grainy, summits, criminals, restless,
# Average loss at step 62000: 3.240123
# Average loss at step 64000: 3.252422
# Average loss at step 66000: 3.403664
# Average loss at step 68000: 3.393819
# Average loss at step 70000: 3.356544
# Nearest to these: many, such, some, several, those, are, which, they,
# Nearest to their: its, his, her, the, our, whose, your, some,
# Nearest to to: can, would, substituting, forgets, will, must, rowan, may,
# Nearest to are: were, have, is, these, those, although, including, be,
# Nearest to were: are, have, was, had, be, been, being, lvares,
# Nearest to have: had, has, were, are, include, be, require, counseling,
# Nearest to some: many, several, these, various, those, most, both, all,
# Nearest to people: men, children, women, those, shaughnessy, zubaydah, historians, elmore,
# Nearest to in: within, during, on, among, throughout, including, for, hickman,
# Nearest to who: he, she, they, luxurious, pronouns, never, generally, overvalued,
# Nearest to also: often, now, still, which, generally, sometimes, never, usually,
# Nearest to about: over, oldies, supper, parnassus, on, hellish, comma, garbled,
# Nearest to one: two, seven, six, four, eight, five, three, nine,
# Nearest to but: however, although, though, that, while, which, and, see,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Nearest to world: enforcing, nikolay, attainder, progress, grainy, caracalla, playfulness, largest,
# Average loss at step 72000: 3.373345
# Average loss at step 74000: 3.347692
# Average loss at step 76000: 3.315446
# Average loss at step 78000: 3.351337
# Average loss at step 80000: 3.377052
# Nearest to these: several, those, many, both, some, such, various, multiple,
# Nearest to their: its, her, his, your, our, my, whose, the,
# Nearest to to: gallop, will, would, barbarian, reissue, eavesdropping, kinshasa, anconia,
# Nearest to are: were, have, is, include, although, those, discerned, including,
# Nearest to were: are, had, have, was, been, be, became, being,
# Nearest to have: had, has, were, are, be, require, include, having,
# Nearest to some: many, several, these, various, those, most, any, both,
# Nearest to people: men, children, women, shaughnessy, person, historians, those, zubaydah,
# Nearest to in: during, within, on, until, at, since, through, essai,
# Nearest to who: he, she, they, never, still, ever, which, pronouns,
# Nearest to also: often, now, still, which, sometimes, gerd, generally, never,
# Nearest to about: oldies, over, garbled, comma, soundtracks, parnassus, downer, liners,
# Nearest to one: six, seven, two, three, eight, four, five, nine,
# Nearest to but: however, although, while, and, tabloid, which, than, piast,
# Nearest to may: can, could, would, must, will, should, might, cannot,
# Nearest to world: enforcing, progress, attainder, caracalla, criminals, nikolay, playfulness, androgen,
# Average loss at step 82000: 3.409399
# Average loss at step 84000: 3.409676
# Average loss at step 86000: 3.389861
# Average loss at step 88000: 3.349880
# Average loss at step 90000: 3.362529
# Nearest to these: several, many, some, those, both, multiple, various, such,
# Nearest to their: its, his, her, our, your, whose, my, the,
# Nearest to to: mamadou, gallop, would, will, bahama, pigeons, reissue, forgets,
# Nearest to are: were, is, include, have, these, although, discerned, molson,
# Nearest to were: are, was, had, have, while, lvares, although, those,
# Nearest to have: had, has, were, be, require, are, include, having,
# Nearest to some: many, several, these, those, most, any, both, all,
# Nearest to people: men, children, women, historians, person, shaughnessy, man, cooperating,
# Nearest to in: during, within, under, with, at, between, near, gilman,
# Nearest to who: he, she, which, also, they, pronouns, often, actually,
# Nearest to also: often, now, which, still, generally, never, sometimes, actually,
# Nearest to about: oldies, over, comma, downer, columbo, garbled, hellish, soundtracks,
# Nearest to one: seven, eight, two, four, six, five, three, nine,
# Nearest to but: however, although, and, which, until, that, piast, while,
# Nearest to may: can, could, must, would, will, might, should, cannot,
# Nearest to world: enforcing, progress, attainder, luz, androgen, caracalla, maidens, summits,
# Average loss at step 92000: 3.400867
# Average loss at step 94000: 3.249729
# Average loss at step 96000: 3.354111
# Average loss at step 98000: 3.243996
# Average loss at step 100000: 3.360782
# Nearest to these: several, some, those, many, all, multiple, various, were,
# Nearest to their: its, his, her, our, your, whose, the, my,
# Nearest to to: will, would, could, must, gallop, can, should, mamadou,
# Nearest to are: were, have, is, be, include, while, although, these,
# Nearest to were: are, have, was, these, although, had, lvares, those,
# Nearest to have: had, has, require, were, are, contain, include, be,
# Nearest to some: many, several, these, any, those, various, certain, energetically,
# Nearest to people: men, children, women, historians, jews, person, cultures, shaughnessy,
# Nearest to in: during, within, among, until, from, throughout, on, at,
# Nearest to who: he, never, she, actually, often, still, which, we,
# Nearest to also: now, still, often, never, sometimes, generally, actually, which,
# Nearest to about: oldies, over, downer, garbled, parnassus, hellish, approximately, qoheleth,
# Nearest to one: two, four, three, seven, nine, eight, five, six,
# Nearest to but: however, although, and, which, though, while, ugly, that,
# Nearest to may: can, could, should, might, must, would, will, cannot,
# Nearest to world: enforcing, attainder, luz, progress, bront, inaccurately, cairns, caracalla,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# See https://discussions.udacity.com/t/assignment-5-general-understanding-of-cbow-vs-skip-gram-model/46393/18

# %%
data_index = 0

def generate_batch_cbow(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size // num_skips, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    #print("target : {}".format(target))
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i 
            * num_skips + j] = buffer[target]
      
    labels[i , 0] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8 // num_skips)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#     labels: ['originated', 'as', 'a', 'term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['term', 'anarchism', 'originated', 'a', 'originated', 'as', 'of', 'term']
#     labels: ['as', 'a']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size // num_skips, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  segments = tf.constant([x // num_skips for x in range(batch_size)])
    
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  embed = tf.segment_sum(embed, segments)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.935206
# Nearest to two: swears, courson, statement, khaled, benefiting, unreliable, sealand, ili,
# Nearest to most: neural, cult, typewriter, developments, carps, tabs, notional, alienate,
# Nearest to united: finals, spirits, escudo, dinara, cenotaph, isolate, scale, rosenberg,
# Nearest to not: megafauna, chaucer, pans, acquaintance, hires, cabell, undercoat, hellenism,
# Nearest to th: thereabouts, ly, stipulate, cowper, chun, outputs, economical, ascent,
# Nearest to the: oj, muscovy, altair, anarchistic, maccabean, moby, footed, noether,
# Nearest to in: luthier, exmouth, ribera, trenton, chainsaw, minima, destabilize, franjo,
# Nearest to and: mishandling, robespierre, convalescence, schleicher, duration, shadow, pitot, warming,
# Nearest to also: torquato, chemnitz, predication, flights, brushed, koine, sensors, retellings,
# Nearest to his: alicante, byzantine, assassination, narcotics, days, mia, schliemann, retinal,
# Nearest to history: triangulation, channing, colchis, sprinkling, sterile, tongues, biased, sox,
# Nearest to american: diena, galaxy, santorini, wishes, maximian, pipelined, electors, dur,
# Nearest to than: soldering, impasse, handmade, parton, discography, traveling, certificate, historians,
# Nearest to were: digby, microscopic, tailpiece, classis, hierarchically, frigates, kent, stewards,
# Nearest to use: molybdenum, limbo, multihull, intimately, flourish, reappears, jailed, virginals,
# Nearest to has: interfacing, vip, stomachs, borzoi, vardar, cidre, hyperinsulinism, drowning,
# Average loss at step 2000: 4.227451
# Average loss at step 4000: 3.649348
# Average loss at step 6000: 3.540671
# Average loss at step 8000: 3.379809
# Average loss at step 10000: 3.297669
# Nearest to two: five, eight, seven, three, six, four, nine, zero,
# Nearest to most: seminars, many, fascist, fontane, crews, standardize, gutnish, more,
# Nearest to united: finals, esso, mccarthy, dinara, nordisk, escudo, transliteration, researcher,
# Nearest to not: you, still, there, it, they, never, sometimes, often,
# Nearest to th: stipulate, thereabouts, intermediaries, lothian, loony, deuteronomic, deluge, donor,
# Nearest to the: its, a, his, this, each, an, their, leukemia,
# Nearest to in: of, at, on, daniell, after, dyson, lilongwe, goldstein,
# Nearest to and: or, swampy, shearer, fanaticism, discern, american, labored, edomites,
# Nearest to also: often, which, who, usually, now, doorways, skater, sometimes,
# Nearest to his: her, their, its, the, wff, grating, trakai, atomists,
# Nearest to history: dictates, podcast, cfc, umbilical, corner, hata, baha, phantoms,
# Nearest to american: brands, willughby, parker, wiltshire, diena, gauge, gail, mongol,
# Nearest to than: entails, or, historicism, universities, much, cards, bake, dah,
# Nearest to were: are, was, been, have, is, being, had, he,
# Nearest to use: aberdare, emeralds, limbo, virginals, brinkley, river, verus, marrying,
# Nearest to has: had, have, was, is, allgemeine, hyperinsulinism, reap, summa,
# Average loss at step 12000: 3.278929
# Average loss at step 14000: 3.239918
# Average loss at step 16000: 3.019874
# Average loss at step 18000: 3.060506
# Average loss at step 20000: 3.158644
# Nearest to two: three, four, six, eight, seven, five, zero, one,
# Nearest to most: many, more, some, quite, eu, predecessors, fascist, lamiales,
# Nearest to united: esso, finals, latter, remaining, negation, escudo, eastern, southern,
# Nearest to not: also, still, often, usually, sometimes, never, therefore, you,
# Nearest to th: intermediaries, nd, three, deuteronomic, eight, trowa, puppy, cmp,
# Nearest to the: his, their, its, nolan, ideologically, an, a, another,
# Nearest to in: under, during, at, on, from, across, afrobeat, inborn,
# Nearest to and: or, but, at, anac, in, however, dataset, dueling,
# Nearest to also: now, still, often, never, not, which, doorways, boole,
# Nearest to his: her, their, its, the, our, wff, compel, my,
# Nearest to history: collapse, saud, list, hair, affords, encounters, hrer, consented,
# Nearest to american: british, australian, french, willughby, pathologies, highbury, limestone, german,
# Nearest to than: or, zine, entails, alteration, tougher, historicism, musicianship, kinetoscope,
# Nearest to were: are, had, was, is, have, tsuba, be, privatize,
# Nearest to use: emeralds, aberdare, verus, brinkley, skies, coens, marrying, noboa,
# Nearest to has: had, have, was, is, having, preterist, summa, stats,
# Average loss at step 22000: 3.118373
# Average loss at step 24000: 3.081559
# Average loss at step 26000: 3.050075
# Average loss at step 28000: 3.069219
# Average loss at step 30000: 3.078750
# Nearest to two: seven, three, one, six, four, five, eight, nine,
# Nearest to most: many, some, more, fontane, branching, spans, townspeople, criss,
# Nearest to united: esso, negation, latter, finals, byzantine, southern, nordisk, escudo,
# Nearest to not: still, therefore, often, also, emeritus, never, predictive, eminently,
# Nearest to th: nd, six, rd, skipping, eight, puppy, vanes, intermediaries,
# Nearest to the: their, some, his, our, these, its, any, wipes,
# Nearest to in: during, under, into, within, at, throughout, until, of,
# Nearest to and: or, veins, however, while, in, stifle, inhibits, arcy,
# Nearest to also: often, still, never, always, now, usually, below, sometimes,
# Nearest to his: her, their, my, its, your, our, the, s,
# Nearest to history: journal, art, waff, collection, deforest, style, sparingly, aristotle,
# Nearest to american: english, national, australian, british, canadian, limestone, indian, italian,
# Nearest to than: but, much, ips, sca, aziz, pretender, alteration, tougher,
# Nearest to were: are, was, have, mpc, been, became, revamped, had,
# Nearest to use: brinkley, chalukyas, aberdare, remainder, emeralds, entertain, influence, infix,
# Nearest to has: had, have, was, is, having, then, preterist, reith,
# Average loss at step 32000: 3.077696
# Average loss at step 34000: 3.058509
# Average loss at step 36000: 3.003818
# Average loss at step 38000: 2.793440
# Average loss at step 40000: 2.979160
# Nearest to two: four, six, three, five, seven, eight, one, nine,
# Nearest to most: more, very, quite, some, particularly, predecessors, spans, calvino,
# Nearest to united: esso, negation, finals, remaining, escudo, southern, middle, sovereign,
# Nearest to not: never, still, therefore, now, you, beuve, generally, restored,
# Nearest to th: rd, puppy, distributors, intermediaries, st, nd, thurber, seventh,
# Nearest to the: any, each, their, this, appeasement, a, its, another,
# Nearest to in: from, of, during, within, at, with, and, albinus,
# Nearest to and: or, but, including, in, whose, nicknamed, while, e,
# Nearest to also: still, always, often, never, sometimes, usually, generally, typically,
# Nearest to his: their, her, its, my, your, our, whose, the,
# Nearest to history: queueing, collection, university, aristotle, philosophy, journal, esperanto, art,
# Nearest to american: british, australian, irish, french, german, russian, english, canadian,
# Nearest to than: or, aziz, hand, obtain, tougher, historicism, seashore, pretender,
# Nearest to were: are, was, have, mpc, being, those, include, loosely,
# Nearest to use: refer, brinkley, form, way, hear, seek, support, subliminal,
# Nearest to has: had, have, was, is, contains, showed, having, traditionally,
# Average loss at step 42000: 2.984979
# Average loss at step 44000: 2.993189
# Average loss at step 46000: 2.979694
# Average loss at step 48000: 2.875938
# Average loss at step 50000: 2.900657
# Nearest to two: six, three, four, eight, seven, five, one, zero,
# Nearest to most: more, particularly, some, less, predecessors, many, whomever, quite,
# Nearest to united: esso, negation, rear, southern, coiled, finals, resonated, marriageable,
# Nearest to not: never, still, always, generally, therefore, actually, now, also,
# Nearest to th: three, seventeenth, intermediaries, six, seventh, rd, four, nd,
# Nearest to the: its, a, their, his, this, our, opted, an,
# Nearest to in: within, during, until, throughout, on, from, at, of,
# Nearest to and: or, including, hawaiian, arcy, magellanic, whose, incited, but,
# Nearest to also: still, often, now, never, typically, sometimes, which, generally,
# Nearest to his: their, her, its, my, your, whose, the, our,
# Nearest to history: collection, intricately, despot, story, aristotle, period, study, list,
# Nearest to american: australian, irish, chinese, european, indian, scottish, russian, italian,
# Nearest to than: chthonic, tougher, much, but, or, occurrences, zine, combinatorial,
# Nearest to were: are, was, have, been, remain, mpc, had, exist,
# Nearest to use: subliminal, remainder, result, brinkley, form, sense, cause, scenarios,
# Nearest to has: had, have, is, was, contains, includes, having, makes,
# Average loss at step 52000: 2.959893
# Average loss at step 54000: 2.936484
# Average loss at step 56000: 2.960697
# Average loss at step 58000: 2.874035
# Average loss at step 60000: 2.889083
# Nearest to two: three, one, four, five, seven, six, eight, nine,
# Nearest to most: many, eu, particularly, whomever, deserving, some, aide, predecessors,
# Nearest to united: esso, negation, southern, marriageable, byzantine, climbing, hgp, coiled,
# Nearest to not: still, now, never, generally, beuve, harms, actually, always,
# Nearest to th: rd, nd, fifth, nine, six, cowan, seventeenth, eight,
# Nearest to the: its, their, this, our, a, his, dissenting, ideologically,
# Nearest to in: within, throughout, during, among, since, through, between, of,
# Nearest to and: or, but, including, abbahu, sociolinguistics, antietam, doha, include,
# Nearest to also: now, still, generally, typically, actually, often, never, sometimes,
# Nearest to his: her, their, my, its, our, your, the, whose,
# Nearest to history: relativity, colosseum, tanned, development, philosophy, story, reunions, alphabetic,
# Nearest to american: indian, australian, irish, european, chinese, british, italian, crono,
# Nearest to than: chthonic, much, aziz, hand, transmissions, slightly, ignited, far,
# Nearest to were: are, have, remain, was, including, had, be, hated,
# Nearest to use: brinkley, because, importance, content, form, support, method, popularity,
# Nearest to has: had, have, is, contains, was, includes, having, berklee,
# Average loss at step 62000: 2.684295
# Average loss at step 64000: 2.700292
# Average loss at step 66000: 2.874445
# Average loss at step 68000: 2.897854
# Average loss at step 70000: 2.832559
# Nearest to two: three, six, four, one, seven, five, eight, nine,
# Nearest to most: less, more, many, predecessors, instances, particularly, very, highly,
# Nearest to united: negation, esso, nation, sovereign, byzantine, independent, communist, marriageable,
# Nearest to not: still, generally, now, never, always, rarely, therefore, actually,
# Nearest to th: fifth, rd, seventh, cowan, lifeboat, fourth, seventeenth, sixth,
# Nearest to the: its, their, a, any, this, whose, our, each,
# Nearest to in: within, during, throughout, until, on, if, through, for,
# Nearest to and: or, while, which, but, of, however, antikythera, boulez,
# Nearest to also: still, now, actually, never, generally, often, sometimes, typically,
# Nearest to his: her, their, my, your, our, its, wff, whose,
# Nearest to history: list, caricatures, irvine, tanned, art, philosophy, marriott, disbanded,
# Nearest to american: australian, indian, british, european, italian, irish, toro, english,
# Nearest to than: but, aziz, much, chthonic, duckburg, least, sca, or,
# Nearest to were: are, have, was, be, had, include, tend, is,
# Nearest to use: share, need, blasphemous, form, importance, call, brinkley, because,
# Nearest to has: had, have, is, contains, was, berklee, having, gives,
# Average loss at step 72000: 2.858286
# Average loss at step 74000: 2.826021
# Average loss at step 76000: 2.823553
# Average loss at step 78000: 2.822867
# Average loss at step 80000: 2.854816
# Nearest to two: three, four, five, six, eight, seven, one, nine,
# Nearest to most: many, some, predecessors, more, particularly, less, instances, especially,
# Nearest to united: negation, independent, netherlands, esso, nation, sovereign, hgp, byzantine,
# Nearest to not: actually, still, never, always, generally, rarely, therefore, now,
# Nearest to th: fourth, sixth, fifth, eighth, nd, bc, seventeenth, rd,
# Nearest to the: its, a, his, this, each, your, their, my,
# Nearest to in: during, within, on, until, throughout, of, at, after,
# Nearest to and: or, including, forcible, while, but, opposes, overdosing, magellanic,
# Nearest to also: still, now, sometimes, never, actually, often, typically, chemnitz,
# Nearest to his: her, my, their, your, our, its, the, whose,
# Nearest to history: tanned, caricatures, irvine, proverbial, radiology, lobbyist, introduction, study,
# Nearest to american: australian, british, austrian, international, irish, russian, italian, elaborate,
# Nearest to than: much, chthonic, while, or, but, accurately, obtain, require,
# Nearest to were: are, had, have, was, include, remain, began, been,
# Nearest to use: share, form, content, proportion, importance, brinkley, outbreak, flue,
# Nearest to has: had, have, is, was, since, having, makes, contains,
# Average loss at step 82000: 2.879211
# Average loss at step 84000: 2.892501
# Average loss at step 86000: 2.860316
# Average loss at step 88000: 2.810155
# Average loss at step 90000: 2.818338
# Nearest to two: three, six, four, seven, five, eight, one, nine,
# Nearest to most: more, some, predecessors, less, many, onesimus, thematic, clerks,
# Nearest to united: negation, sovereign, netherlands, hgp, baptist, uk, nls, marriageable,
# Nearest to not: actually, still, now, we, never, otherwise, also, quite,
# Nearest to th: st, rd, seven, fourth, fifth, eighth, seventeenth, sixth,
# Nearest to the: his, its, this, each, a, whose, their, every,
# Nearest to in: within, during, near, under, of, at, while, among,
# Nearest to and: or, but, while, arcy, vs, including, through, boyne,
# Nearest to also: actually, now, often, still, never, sometimes, generally, usually,
# Nearest to his: her, their, its, our, your, my, whose, the,
# Nearest to history: list, tanned, caricatures, lacan, vulture, story, selection, uri,
# Nearest to american: australian, austrian, british, italian, irish, indian, european, german,
# Nearest to than: or, much, funimation, sca, assemblers, dtmf, realistic, pretender,
# Nearest to were: are, had, have, was, while, tend, been, mpc,
# Nearest to use: share, brinkley, proportion, result, support, need, treatment, importance,
# Nearest to has: had, have, is, makes, was, since, requires, having,
# Average loss at step 92000: 2.861626
# Average loss at step 94000: 2.689383
# Average loss at step 96000: 2.831578
# Average loss at step 98000: 2.682763
# Average loss at step 100000: 2.814848
# Nearest to two: six, three, four, five, seven, eight, one, nine,
# Nearest to most: more, predecessors, less, metaxas, especially, extremely, legnica, navigable,
# Nearest to united: negation, sovereign, baptist, netherlands, hgp, baltic, nation, communist,
# Nearest to not: actually, never, otherwise, always, now, harms, airfields, completely,
# Nearest to th: seventh, eighth, rd, fourth, fifth, thurber, sixth, nd,
# Nearest to the: their, your, his, its, a, our, my, this,
# Nearest to in: within, during, throughout, under, across, near, of, ams,
# Nearest to and: or, when, although, while, but, wracked, forcible, interpretative,
# Nearest to also: actually, never, now, always, still, often, sometimes, traditionally,
# Nearest to his: their, her, your, our, its, my, the, whose,
# Nearest to history: tanned, brightest, production, list, selection, dahalo, yoakum, recourse,
# Nearest to american: australian, british, canadian, italian, russian, austrian, irish, international,
# Nearest to than: chthonic, or, funimation, liberians, obtain, suited, fated, races,
# Nearest to were: are, have, had, was, tend, including, those, mpc,
# Nearest to use: form, support, share, proportion, application, lack, cause, brinkley,
# Nearest to has: had, have, was, is, since, having, belongs, requires,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# Skip-gram:
# * works well with small amount of the training data
# * represents well even rare words or phrases
#
# CBOW:
# * several times faster to train than skip-gram
# * slightly better accuracy for the frequent words
